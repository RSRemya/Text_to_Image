# %%
pip install gradio-client
# Out:
# Collecting gradio-client
#   Downloading gradio_client-1.5.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client) (2024.10.0)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio-client) (0.28.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from gradio-client) (0.26.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio-client) (24.2)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client) (4.12.2)
# Collecting websockets<15.0,>=10.0 (from gradio-client)
#   Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio-client) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio-client) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio-client) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio-client) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio-client) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio-client) (3.16.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio-client) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio-client) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio-client) (4.66.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio-client) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio-client) (1.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->gradio-client) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->gradio-client) (2.2.3)
# Downloading gradio_client-1.5.1-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.2/320.2 kB 7.3 MB/s eta 0:00:00
# Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 12.1 MB/s eta 0:00:00
# Installing collected packages: websockets, gradio-client
# Successfully installed gradio-client-1.5.1 websockets-14.1

# %%
from gradio_client import Client
from PIL import Image
from IPython.display import display

client = Client("prithivMLmods/FLUX-REALISM")
result = client.predict(
        prompt="A girl in black dress",
        seed=42,
        width=520,
        height=520,
        guidance_scale=6,
        randomize_seed=False,
        api_name="/run"
        #takes minimum of 30 seconds
)
print(result)

# Path to the generated image
img_path = result[0][0]['image']

# Open and display the image
img = Image.open(img_path)
display(img)
# Out:
# Loaded as API: https://prithivmlmods-flux-1-realism.hf.space ✔
# ([{'image': '/tmp/gradio/b90f7f0c0c39d37ab383d5d20f134b0b50d2dee65a836c75a62ff64431db75ad/0ce5b7c6-2d4d-48fd-8266-85cda536873e.png', 'caption': None}], 42)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
from gradio_client import Client
from PIL import Image
from IPython.display import display

client = Client("prithivMLmods/FLUX-REALISM")
result = client.predict(
        prompt="Astronaut on horse",
        seed=42,
        width=520,
        height=520,
        guidance_scale=6,
        randomize_seed=False,
        api_name="/run"
        #takes minimum of 30 seconds
)
print(result)

# Path to the generated image
img_path = result[0][0]['image']

# Open and display the image
img = Image.open(img_path)
display(img)
# Out:
# Loaded as API: https://prithivmlmods-flux-1-realism.hf.space ✔
# ([{'image': '/tmp/gradio/8904da6aa45968e04e34fef7a0a9b7620fa5b288568fe1ce6bad62cd51a985c3/e6ab2e1b-c187-4ccf-87c7-390902705818.png', 'caption': None}], 42)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
from gradio_client import Client
from PIL import Image
from IPython.display import display

client = Client("prithivMLmods/FLUX-REALISM")
result = client.predict(
        prompt="Donald Trump eating Biriyani",
        seed=42,
        width=520,
        height=520,
        guidance_scale=6,
        randomize_seed=False,
        api_name="/run"
        #takes minimum of 30 seconds
)
print(result)

# Path to the generated image
img_path = result[0][0]['image']

# Open and display the image
img = Image.open(img_path)
display(img)
# Out:
# Loaded as API: https://prithivmlmods-flux-1-realism.hf.space ✔
# ([{'image': '/tmp/gradio/7c9c9054ae2acaad9b5f55cde672fb7c9a619cacaa3f6a2cab781f5908979a11/a177414b-e2ca-41e8-a6d2-ec469bbf752b.png', 'caption': None}], 42)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>
